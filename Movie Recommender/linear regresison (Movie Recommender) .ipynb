# %%
from sklearn import datasets
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np

# %%
review_data = pd.read_csv(r'sented_aud.csv')
review_data
# Out:
#              aud                                             review  \
# 0     Benjamin S  Major missed opportunity not getting Rick Mora...
# 1        Clyde N                      I really liked it and idk why
# 2        Wyatt G  This is a fun heist movie that is non-stop hil...
# 3       Nathan M  not funny or even decent but the action is ser...
# 4         Jake M  honestly its great. just the final fight felt ...
# ...          ...                                                ...
# 4870      Adis M  2 points for Scarlett Johansson, the film is u...
# 4871     Brian P   An actual good movie, one of the top in the MCU.
# 4872      Kian M  This movie was great love the sound track for ...
# 4873     James H  Captain America: The Winter Soldier surpasses ...
# 4874     Enoch T  My God. What a movie. Everything that I hated ...
#
#            date  rate    neg    neu    pos  compound  Unnamed: 8  Unnamed: 9  \
# ...

# %%
data = review_data.drop(['aud','review','date','Unnamed: 8','Unnamed: 9','Unnamed: 10','count','Unnamed: 12','Unnamed: 13','compound'], axis=1)

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
normal_data = review_data[['neg','neu','pos','compound']]

# %%
corr = normal_data.corr()
corr
# Out:
#                neg       neu       pos  compound
# neg       1.000000 -0.269957 -0.423888 -0.675527
# neu      -0.269957  1.000000 -0.757654 -0.183086
# pos      -0.423888 -0.757654  1.000000  0.630102
# compound -0.675527 -0.183086  0.630102  1.000000

# %%
ax = sns.heatmap(corr, center=0)

# %%
data.dropna()
# Out:
#       rate    neg    neu    pos
# 0      3.0  0.019  0.603  0.378
# 1      3.0  0.165  0.471  0.364
# 2      3.0  0.109  0.695  0.196
# 3      3.0  0.146  0.854  0.000
# 4      3.0  0.156  0.419  0.425
# ...    ...    ...    ...    ...
# 4870   5.0  0.187  0.633  0.180
# 4871   5.0  0.000  0.657  0.343
# 4872   5.0  0.129  0.420  0.451
# 4873   5.0  0.000  0.956  0.044
# 4874   5.0  0.171  0.571  0.257
#
# [4858 rows x 4 columns]

# %%
import statsmodels.api as sm
data[np.isnan(data)] = 0
data[np.isinf(data)] = 0

# %%
y = data['rate']
x = data.drop(['rate'],axis = 1)

# %%
X = sm.add_constant(x) 
full_model = sm.OLS(y, x).fit()
full_model.summary()
# Out:
# /Users/hh/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   rate   R-squared (uncentered):                   0.874
# Model:                            OLS   Adj. R-squared (uncentered):              0.874
# Method:                 Least Squares   F-statistic:                          1.128e+04
# Date:                Fri, 26 Aug 2022   Prob (F-statistic):                        0.00
# Time:                        17:40:09   Log-Likelihood:                         -8348.2
# No. Observations:                4875   AIC:                                  1.670e+04
# Df Residuals:                    4872   BIC:                                  1.672e+04
# ...
